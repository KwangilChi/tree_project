# %%
import csv 

filename = "/home/campus-5/Documents/Project_arbre 2019 01 16/0. Data/ESP_PUBLIC.IDENTITE_ARBRE.csv"

dataset = list(csv.reader(open(filename)))

# %%
data_labels = dataset.pop(0)

# %%
dataset
# Out:
# [['31906',
#   'ESP32632',
#   'ESP32632',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR32632',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74072726311972,45.1905385120349]}'],
#  ['31905',
#   'ESP32631',
#   'ESP32631',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR32631',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74074817449951,45.190524547693]}'],
#  ['31904',
#   'ESP32630',
#   'ESP32630',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR32630',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74069739487812,45.1904979371376]}'],
#  ['31903',
#   'ESP32629',
#   'ESP32629',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR32629',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74067549670718,45.1904912803012]}'],
#  ['31902',
#   'ESP32628',
#   'ESP32628',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR32628',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74070156563956,45.1904789877616]}'],
#  ['31123',
#   'ESP31995',
#   'ESP31995',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR31995',
#   'Quercus',
#   'cerris',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73982777571091,45.1912288598277]}'],
#  ['30467',
#   'ESP31576',
#   'ESP31576',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR31576',
#   'Quercus',
#   'frainetto',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73998334628571,45.1893359611052]}'],
#  ['24188',
#   'ESP20708',
#   'ESP20708',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20708',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74426852918541,45.1883332395282]}'],
#  ['24186',
#   'ESP20707',
#   'ESP20707',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20707',
#   'Salix',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74103748957106,45.1891268275518]}'],
#  ['24185',
#   'ESP20706',
#   'ESP20706',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20706',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74052279217689,45.1891078427493]}'],
#  ['24144',
#   'ESP20696',
#   'ESP20696',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20696',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74072605700985,45.1899212448905]}'],
#  ['5579',
#   'ESP20621',
#   'ESP20621',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20621',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74069063897945,45.1903902996876]}'],
#  ['5577',
#   'ESP20620',
#   'ESP20620',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20620',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74055024173756,45.1904241319122]}'],
#  ['5575',
#   'ESP20619',
#   'ESP20619',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20619',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74081861609215,45.1892819947713]}'],
#  ['5503',
#   'ESP20618',
#   'ESP20618',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20618',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74077264560191,45.1895236866859]}'],
#  ['20482',
#   'ESP20308',
#   'ESP20308',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20308',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74058124888998,45.1903693576309]}'],
#  ['20480',
#   'ESP20307',
#   'ESP20307',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20307',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74078402240275,45.1891763509103]}'],
#  ['20429',
#   'ESP20292',
#   'ESP20292',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20292',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74032371422101,45.1896992014524]}'],
#  ['20427',
#   'ESP20291',
#   'ESP20291',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20291',
#   'Prunus',
#   'domestica',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74107118735334,45.189093429082]}'],
#  ['20388',
#   'ESP20278',
#   'ESP20278',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20278',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74014679009344,45.1894984959603]}'],
#  ['20385',
#   'ESP20277',
#   'ESP20277',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20277',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74095062016578,45.1891209611858]}'],
#  ['20381',
#   'ESP20276',
#   'ESP20276',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20276',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73947130609935,45.1908460548384]}'],
#  ['20411',
#   'ESP20286',
#   'ESP20286',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR20286',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.7386501280297,45.1712955269188]}'],
#  ['20410',
#   'ESP20285',
#   'ESP20285',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR20285',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73873754574475,45.171123357456]}'],
#  ['9310',
#   'ESP13726',
#   'ESP13726',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR13726',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73871905223067,45.1711600271676]}'],
#  ['5518',
#   'ESP11854',
#   'ESP11854',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR11854',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73875260323049,45.171093244957]}'],
#  ['27826',
#   'ESP7715',
#   'ESP7715',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR7715',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73881431443525,45.1709698249205]}'],
#  ['24118',
#   'ESP7125',
#   'ESP7125',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR7125',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73879693285096,45.1710046070597]}'],
#  ['16775',
#   'ESP6308',
#   'ESP6308',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR6308',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73868396288604,45.1712290246041]}'],
#  ['9309',
#   'ESP4928',
#   'ESP4928',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR4928',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.738701833,45.1711938860062]}'],
#  ['5519',
#   'ESP3414',
#   'ESP3414',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR3414',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73866544083548,45.171265424981]}'],
#  ['1716',
#   'ESP2240',
#   'ESP2240',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1005',
#   'R Ninon Vallin park',
#   '5',
#   'AR2240',
#   'Acer',
#   'pseudoplatanus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1969',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73878250137754,45.171033449536]}'],
#  ['20414',
#   'ESP24223',
#   'ESP24223',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR24223',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73909748279256,45.1666015717293]}'],
#  ['13129',
#   'ESP23025',
#   'ESP23025',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR23025',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73916907408494,45.1665499400448]}'],
#  ['16778',
#   'ESP19328',
#   'ESP19328',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR19328',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73932364700963,45.1664599232768]}'],
#  ['9314',
#   'ESP13728',
#   'ESP13728',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR13728',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73979515628139,45.1663123131823]}'],
#  ['5520',
#   'ESP11855',
#   'ESP11855',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR11855',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73958698373495,45.1663599258865]}'],
#  ['1719',
#   'ESP9797',
#   'ESP9797',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR9797',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73949739452255,45.1663871848052]}'],
#  ['9315',
#   'ESP4931',
#   'ESP4931',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR4931',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73894364933957,45.1667593669868]}'],
#  ['9313',
#   'ESP4930',
#   'ESP4930',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR4930',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73989195969716,45.1662989361905]}'],
#  ['13128',
#   'ESP4319',
#   'ESP4319',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR4319',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.7396870064264,45.1663338925853]}'],
#  ['5521',
#   'ESP3415',
#   'ESP3415',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1006',
#   'R R Descartes',
#   '5',
#   'AR3415',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1965',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.73924571759225,45.166503077404]}'],
#  ['9319',
#   'ESP13731',
#   'ESP13731',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1007',
#   'R Marius Riollet cité rouge',
#   '5',
#   'AR13731',
#   'Liriodendron',
#   'tulipifera',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2003',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74840648462399,45.1771818611241]}'],
#  ['5524',
#   'ESP11857',
#   'ESP11857',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1007',
#   'R Marius Riollet cité rouge',
#   '5',
#   'AR11857',
#   'Liriodendron',
#   'tulipifera',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2003',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74844574361786,45.1770253426428]}'],
#  ['13130',
#   'ESP4320',
#   'ESP4320',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1007',
#   'R Marius Riollet cité rouge',
#   '5',
#   'AR4320',
#   'Liriodendron',
#   'tulipifera',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2003',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74842532519548,45.1771040437636]}'],
#  ['16780',
#   'ESP31157',
#   'ESP31157',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31157',
#   'Pinus',
#   'nigra',
#   'Austriaca',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Basse',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75166780403672,45.1723124899152]}'],
#  ['27830',
#   'ESP30807',
#   'ESP30807',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR30807',
#   'Acer',
#   'campestre',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75095156831185,45.1724791710149]}'],
#  ['27829',
#   'ESP28921',
#   'ESP28921',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR28921',
#   'Pinus',
#   'nigra',
#   'Austriaca',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Basse',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75168868721759,45.1722793589044]}'],
#  ['13131',
#   'ESP23026',
#   'ESP23026',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR23026',
#   'Acer',
#   'campestre',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75094749400319,45.1724604965826]}'],
#  ['30057',
#   'ESP31304',
#   'ESP31304',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31304',
#   'Chamaecyparis',
#   'lawsoniana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75160748938303,45.1723007331911]}'],
#  ['30056',
#   'ESP31303',
#   'ESP31303',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31303',
#   'Rhus',
#   'typhina',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75120837095707,45.1724176799256]}'],
#  ['30055',
#   'ESP31302',
#   'ESP31302',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31302',
#   'Rhus',
#   'typhina',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75116993472811,45.1724305319176]}'],
#  ['30054',
#   'ESP31301',
#   'ESP31301',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31301',
#   'Rhus',
#   'typhina',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75113324147817,45.1724427142034]}'],
#  ['30053',
#   'ESP31300',
#   'ESP31300',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31300',
#   'Rhus',
#   'typhina',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75110715675836,45.1724540137844]}'],
#  ['30052',
#   'ESP31299',
#   'ESP31299',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR31299',
#   'Rhus',
#   'typhina',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75108655520559,45.1724501140354]}'],
#  ['20415',
#   'ESP20287',
#   'ESP20287',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR20287',
#   'Koelreuteria',
#   'paniculata',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75157735392905,45.1723244943402]}'],
#  ['9321',
#   'ESP13732',
#   'ESP13732',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR13732',
#   'Acer',
#   'campestre',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75096525782456,45.1724885670155]}'],
#  ['5526',
#   'ESP11858',
#   'ESP11858',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR11858',
#   'Pinus',
#   'nigra',
#   'Austriaca',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Basse',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75165219478833,45.1722881655678]}'],
#  ['16779',
#   'ESP6309',
#   'ESP6309',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR6309',
#   'Chamaecyparis',
#   'lawsoniana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75106021357549,45.1724651671815]}'],
#  ['9320',
#   'ESP4933',
#   'ESP4933',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR4933',
#   'Chamaecyparis',
#   'lawsoniana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7510217322154,45.1724749392812]}'],
#  ['5525',
#   'ESP3417',
#   'ESP3417',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP151',
#   'Arbre de voirie',
#   'ESP1008',
#   'R Robespierre tennis plein air',
#   '5',
#   'AR3417',
#   'Koelreuteria',
#   'paniculata',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.75154313972783,45.1723288466893]}'],
#  ['24133',
#   'ESP29879',
#   'ESP29879',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1009',
#   "Av J O caisse d'épargne",
#   '5',
#   'AR29879',
#   'Fraxinus',
#   'americana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74865856136697,45.175443739156]}'],
#  ['9329',
#   'ESP13736',
#   'ESP13736',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1009',
#   "Av J O caisse d'épargne",
#   '5',
#   'AR13736',
#   'Fraxinus',
#   'americana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74841858133138,45.1753920023638]}'],
#  ['24132',
#   'ESP7132',
#   'ESP7132',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1009',
#   "Av J O caisse d'épargne",
#   '5',
#   'AR7132',
#   'Fraxinus',
#   'americana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74857209370573,45.175428427315]}'],
#  ['13139',
#   'ESP4323',
#   'ESP4323',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1009',
#   "Av J O caisse d'épargne",
#   '5',
#   'AR4323',
#   'Fraxinus',
#   'americana',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74848968478513,45.1754112999026]}'],
#  ['24174',
#   'ESP20703',
#   'ESP20703',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1010',
#   'Biblio Abbaye les Bains',
#   '5',
#   'AR20703',
#   'Prunus',
#   'lusitanica',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1977',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74214929549707,45.1792664035791]}'],
#  ['16815',
#   'ESP19338',
#   'ESP19338',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1010',
#   'Biblio Abbaye les Bains',
#   '5',
#   'AR19338',
#   'Cercis',
#   'siliquastrum',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1977',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74191465436619,45.1795049191014]}'],
#  ['1762',
#   'ESP16391',
#   'ESP16391',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1010',
#   'Biblio Abbaye les Bains',
#   '5',
#   'AR16391',
#   'Cercis',
#   'siliquastrum',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1977',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74189307989487,45.1794210702469]}'],
#  ['24175',
#   'ESP8203',
#   'ESP8203',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1010',
#   'Biblio Abbaye les Bains',
#   '5',
#   'AR8203',
#   'Prunus',
#   'lusitanica',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1977',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74216953536188,45.1792321483994]}'],
#  ['39426',
#   'ESP38546',
#   'ESP38546',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1011',
#   'Prc Mis stab nord ann vitesse',
#   '5',
#   'AR38546',
#   'Quercus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '{"type":"Point","coordinates":[5.73651965443513,45.1846154871807]}'],
#  ['39425',
#   'ESP38545',
#   'ESP38545',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1011',
#   'Prc Mis stab nord ann vitesse',
#   '5',
#   'AR38545',
#   'Celtis',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '{"type":"Point","coordinates":[5.73636683050665,45.184565920851]}'],
#  ['39424',
#   'ESP38544',
#   'ESP38544',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1011',
#   'Prc Mis stab nord ann vitesse',
#   '5',
#   'AR38544',
#   'Celtis',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '{"type":"Point","coordinates":[5.7361605357438,45.1845014262534]}'],
#  ['39423',
#   'ESP38543',
#   'ESP38543',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1011',
#   'Prc Mis stab nord ann vitesse',
#   '5',
#   'AR38543',
#   'Quercus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '{"type":"Point","coordinates":[5.73621660547337,45.1845889288937]}'],
#  ['39422',
#   'ESP38542',
#   'ESP38542',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1011',
#   'Prc Mis stab nord ann vitesse',
#   '5',
#   'AR38542',
#   'Quercus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '{"type":"Point","coordinates":[5.73627059254721,45.1846900007238]}'],
#  ['39421',
#   'ESP38541',
#   'ESP38541',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1011',
#   'Prc Mis stab nord ann vitesse',
#   '5',
#   'AR38541',
#   'Celtis',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '{"type":"Point","coordinates":[5.73646046979566,45.1847772034299]}'],
#  ['20380',
#   'ESP20275',
#   'ESP20275',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20275',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   'Basse',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73948295499004,45.1909385571592]}'],
#  ['16718',
#   'ESP20144',
#   'ESP20144',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20144',
#   'Populus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73945472638719,45.1893926966015]}'],
#  ['12868',
#   'ESP20076',
#   'ESP20076',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR20076',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74139466012233,45.1895252357106]}'],
#  ['9381',
#   'ESP19765',
#   'ESP19765',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19765',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74042802535943,45.1903619560572]}'],
#  ['9379',
#   'ESP19764',
#   'ESP19764',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19764',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74201071822752,45.1890956890108]}'],
#  ['9286',
#   'ESP19758',
#   'ESP19758',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19758',
#   'Populus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73937903961263,45.1909284422728]}'],
#  ['9283',
#   'ESP19757',
#   'ESP19757',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19757',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73822812488117,45.1907932357267]}'],
#  ['9252',
#   'ESP19746',
#   'ESP19746',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19746',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73962449741404,45.1893161238528]}'],
#  ['16838',
#   'ESP19576',
#   'ESP19576',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19576',
#   'Alnus',
#   'cordata',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2006',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74080985515873,45.1904412001073]}'],
#  ['16836',
#   'ESP19575',
#   'ESP19575',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19575',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74057045845661,45.1904170569356]}'],
#  ['16835',
#   'ESP19574',
#   'ESP19574',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19574',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74056326678658,45.1904007878667]}'],
#  ['16833',
#   'ESP19573',
#   'ESP19573',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19573',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74158096276979,45.1894232401208]}'],
#  ['16831',
#   'ESP19572',
#   'ESP19572',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19572',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74148768764304,45.1895142966408]}'],
#  ['16829',
#   'ESP19571',
#   'ESP19571',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19571',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7412671352837,45.1894327144673]}'],
#  ['13188',
#   'ESP19566',
#   'ESP19566',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19566',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74156747728512,45.1894890921058]}'],
#  ['13184',
#   'ESP19565',
#   'ESP19565',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19565',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74107392692118,45.1894144666777]}'],
#  ['13152',
#   'ESP19556',
#   'ESP19556',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19556',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74079974834987,45.1898138283904]}'],
#  ['13147',
#   'ESP19555',
#   'ESP19555',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19555',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   'Basse',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74101099525594,45.1891983845552]}'],
#  ['13145',
#   'ESP19554',
#   'ESP19554',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19554',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74032450073442,45.1897163246871]}'],
#  ['13066',
#   'ESP19548',
#   'ESP19548',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19548',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73960642082216,45.1893375803445]}'],
#  ['9044',
#   'ESP19445',
#   'ESP19445',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19445',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73957492872308,45.1890836573223]}'],
#  ['16755',
#   'ESP19320',
#   'ESP19320',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19320',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73973715676239,45.1894295182967]}'],
#  ['16751',
#   'ESP19319',
#   'ESP19319',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19319',
#   'Ulmus',
#   'minor',
#   '',
#   'Arbre vieillissant',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74091406019697,45.1910573582209]}'],
#  ['16750',
#   'ESP19318',
#   'ESP19318',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR19318',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73941612552464,45.1911217700938]}'],
#  ['20142',
#   'ESP18095',
#   'ESP18095',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR18095',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73974288491655,45.1908047491604]}'],
#  ['23843',
#   'ESP17861',
#   'ESP17861',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR17861',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73932296094475,45.1910917297403]}'],
#  ['23841',
#   'ESP17860',
#   'ESP17860',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR17860',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74108082028307,45.1892629840984]}'],
#  ['1778',
#   'ESP16403',
#   'ESP16403',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16403',
#   'Alnus',
#   'cordata',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2006',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7408124079286,45.1903250401832]}'],
#  ['1777',
#   'ESP16402',
#   'ESP16402',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16402',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74059734046078,45.1904063650615]}'],
#  ['1774',
#   'ESP16400',
#   'ESP16400',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16400',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73969341080384,45.1892058130306]}'],
#  ['1773',
#   'ESP16399',
#   'ESP16399',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16399',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.73987665069921,45.1893121096695]}'],
#  ['1772',
#   'ESP16398',
#   'ESP16398',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16398',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74155751086659,45.1893869923109]}'],
#  ['1771',
#   'ESP16397',
#   'ESP16397',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16397',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre jeune',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74142767526293,45.1892710942945]}'],
#  ['1770',
#   'ESP16396',
#   'ESP16396',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16396',
#   'Alnus',
#   'cordata',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74029988602852,45.1891846238201]}'],
#  ['1769',
#   'ESP16395',
#   'ESP16395',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16395',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7410481666544,45.1890807690822]}'],
#  ['1768',
#   'ESP16394',
#   'ESP16394',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16394',
#   'Robinia',
#   'pseudoacacia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74004004827841,45.1892788209007]}'],
#  ['1737',
#   'ESP16378',
#   'ESP16378',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16378',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74067935789168,45.1899898161346]}'],
#  ['1736',
#   'ESP16377',
#   'ESP16377',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16377',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74075742887954,45.1898764992772]}'],
#  ['1735',
#   'ESP16376',
#   'ESP16376',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16376',
#   'Fraxinus',
#   'excelsior',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '2001',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74070722059398,45.18994864916]}'],
#  ['1734',
#   'ESP16375',
#   'ESP16375',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP995',
#   'Prc Echangeurs Bastion St Roch',
#   '5',
#   'AR16375',
#   'Acer',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1975',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74061606349999,45.1898624420591]}'],
#  ['1733',
#   'ESP16374',
# ...
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR19844',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74774108598741,45.1789099047227]}'],
#  ['16478',
#   'ESP19843',
#   'ESP19843',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR19843',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74746283262093,45.1791611123119]}'],
#  ['13177',
#   'ESP19564',
#   'ESP19564',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR19564',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.7476483378409,45.1791110176711]}'],
#  ['13173',
#   'ESP19563',
#   'ESP19563',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR19563',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74713809663914,45.1795665000897]}'],
#  ['9035',
#   'ESP19441',
#   'ESP19441',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR19441',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74765603971403,45.179055589878]}'],
#  ['16817',
#   'ESP19339',
#   'ESP19339',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR19339',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74776031011199,45.1787225351086]}'],
#  ['20138',
#   'ESP18094',
#   'ESP18094',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR18094',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74747469116354,45.1790766649364]}'],
#  ['20136',
#   'ESP18093',
#   'ESP18093',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR18093',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7477306823016,45.1787128151694]}'],
#  ['20133',
#   'ESP18092',
#   'ESP18092',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR18092',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74765723343739,45.178828263026]}'],
#  ['23834',
#   'ESP17858',
#   'ESP17858',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR17858',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74758375996914,45.1791040855672]}'],
#  ['1764',
#   'ESP16392',
#   'ESP16392',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR16392',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74760641748409,45.1793038776554]}'],
#  ['1432',
#   'ESP15814',
#   'ESP15814',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR15814',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.7475054284611,45.179079726244]}'],
#  ['1430',
#   'ESP15813',
#   'ESP15813',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR15813',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74774843173276,45.17880711987]}'],
#  ['24179',
#   'ESP15216',
#   'ESP15216',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR15216',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74779623107561,45.1788666839991]}'],
#  ['24176',
#   'ESP15215',
#   'ESP15215',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR15215',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74712445263565,45.179768256669]}'],
#  ['5574',
#   'ESP12364',
#   'ESP12364',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR12364',
#   'Tilia',
#   'tomentosa',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74805188641651,45.1790681114496]}'],
#  ['5571',
#   'ESP12363',
#   'ESP12363',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR12363',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74760329558572,45.1793288235825]}'],
#  ['5223',
#   'ESP11777',
#   'ESP11777',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR11777',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74764564208837,45.1787890698796]}'],
#  ['5220',
#   'ESP11775',
#   'ESP11775',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR11775',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74763465614427,45.1790665727222]}'],
#  ['5573',
#   'ESP11099',
#   'ESP11099',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR11099',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74769080698022,45.179042683808]}'],
#  ['27549',
#   'ESP9060',
#   'ESP9060',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR9060',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7476685146653,45.1788599909255]}'],
#  ['27547',
#   'ESP9059',
#   'ESP9059',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR9059',
#   'Pinus',
#   'sylvestris',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74753227915523,45.1791294494688]}'],
#  ['27545',
#   'ESP9058',
#   'ESP9058',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR9058',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74760769975146,45.1790650215569]}'],
#  ['27543',
#   'ESP9057',
#   'ESP9057',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR9057',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74758954191602,45.1790897688729]}'],
#  ['24184',
#   'ESP8205',
#   'ESP8205',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR8205',
#   'Tilia',
#   'tomentosa',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74808558830224,45.1789828297381]}'],
#  ['23831',
#   'ESP7056',
#   'ESP7056',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR7056',
#   'Pinus',
#   'sylvestris',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.7476612679531,45.1790166150973]}'],
#  ['20469',
#   'ESP6548',
#   'ESP6548',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR6548',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74762318842619,45.1792923996679]}'],
#  ['20139',
#   'ESP6465',
#   'ESP6465',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR6465',
#   'Pinus',
#   'sylvestris',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74755850027225,45.1790945510525]}'],
#  ['20134',
#   'ESP6464',
#   'ESP6464',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR6464',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74756627013756,45.1791771713435]}'],
#  ['16818',
#   'ESP6317',
#   'ESP6317',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR6317',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74782109999087,45.178802197959]}'],
#  ['9369',
#   'ESP4953',
#   'ESP4953',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR4953',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74768808201476,45.1791026484266]}'],
#  ['9036',
#   'ESP4865',
#   'ESP4865',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR4865',
#   'Platanus',
#   'acerifolia',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74737889740046,45.1790563294279]}'],
#  ['12862',
#   'ESP4249',
#   'ESP4249',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR4249',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74764525996333,45.1788086224191]}'],
#  ['5572',
#   'ESP3439',
#   'ESP3439',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR3439',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74764279096873,45.1793205517041]}'],
#  ['5222',
#   'ESP3346',
#   'ESP3346',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR3346',
#   'Magnolia',
#   'grandiflora',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Grenoble Alpes Métropole',
#   '{"type":"Point","coordinates":[5.74730764445736,45.1786899242276]}'],
#  ['5219',
#   'ESP3345',
#   'ESP3345',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR3345',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74773397871467,45.1787315774887]}'],
#  ['1765',
#   'ESP2259',
#   'ESP2259',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR2259',
#   'Pinus',
#   '',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   'Haute',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74779001561426,45.1788258023801]}'],
#  ['1435',
#   'ESP2178',
#   'ESP2178',
#   'VEG',
#   'VEGETATION',
#   'ESP01',
#   'Arbre',
#   'ESP174',
#   "Arbre d'espaces ouverts",
#   'ESP1340',
#   'Cité Chatelet Wash Poincare',
#   '5',
#   'AR2178',
#   'Carpinus',
#   'betulus',
#   '',
#   'Arbre adulte',
#   '',
#   '',
#   '1985',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Ville de Grenoble',
#   '{"type":"Point","coordinates":[5.74739503714824,45.1785577684211]}'],
#  ...]

# %%
data_labels
# Out:
# ['\ufeffELEM_POINT_ID',
#  'CODE',
#  'NOM',
#  'GENRE',
#  'GENRE_DESC',
#  'CATEGORIE',
#  'CATEGORIE_DESC',
#  'SOUS_CATEGORIE',
#  'SOUS_CATEGORIE_DESC',
#  'CODE_PARENT',
#  'CODE_PARENT_DESC',
#  'ADR_SECTEUR',
#  'BIEN_REFERENCE',
#  'GENRE_BOTA',
#  'ESPECE',
#  'VARIETE',
#  'STADEDEDEVELOPPEMENT',
#  'EQUIPE',
#  'REMARQUES',
#  'ANNEEDEPLANTATION',
#  'RAISONDEPLANTATION',
#  'TRAITEMENTCHENILLES',
#  'COURRIER',
#  'IDENTIFIANTPLU',
#  'TYPEIMPLANTATIONPLU',
#  'INTITULEPROTECTIONPLU',
#  'ANNEEABATTAGE',
#  'ESSOUCHEMENT',
#  'DIAMETREARBRE',
#  'CAUSEABATTAGE',
#  'COLLECTIVITE',
#  'GeoJSON']
